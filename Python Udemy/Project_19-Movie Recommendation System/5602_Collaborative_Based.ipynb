# %% [markdown]
# # 3. Collaborative-Based Filtering/ Machine Learning

# %% [markdown]
# ## Load the Data

# %%
import pandas as pd
# ratings = pd.read_csv("data/ratings.csv") # UR
ratings = pd.read_csv("data/ratings.csv")[["userId", "movieId", "rating"]]

# %%
ratings.head() # pyright: ignore
# Out:
#    userId  movieId  rating
# 0       1       31     2.5
# 1       1     1029     3.0
# 2       1     1061     3.0
# 3       1     1129     2.0
# 4       1     1172     4.0

# %% [markdown]
# ## Create the Dataset

# %%
# 'scikit-surprise' not compatible with python-3.13
from surprise import Dataset, Reader

reader = Reader(rating_scale=(1,5)) # i.e. (1 <= rating <= 5).
dataset = Dataset.load_from_df(ratings, reader)
dataset
# From [07:00] of Lecture-426, Section-56.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from surprise import Dataset
#
# ModuleNotFoundError: No module named 'surprise'
