# %%
import pandas as pd

# %%
data_frame = pd.read_csv(r"data_small\TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# <>:1: SyntaxWarning: invalid escape sequence '\T'
# C:\Users\Manas\AppData\Local\Temp\ipykernel_23404\3587904685.py:1: SyntaxWarning: invalid escape sequence '\T'
#   data_frame = pd.read_csv("data_small\TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data_frame = pd.read_csv("data_small\TG_STAID000001.txt", skiprows=20, parse_dates=["    DATE"])
#
# NameError: name 'pd' is not defined

# %%
data_frame
