# %%
print("Hello")
print("Hi")
print("Hi again")
print("Hi")
print("Hi, ")
# Out:
# Hello
# Hi
# Hi again
# Hi
# Hi,

# %%
print("Hi, I am in another cell")
print("Hi, I am Me")
# Out:
# Hi, I am in another cell
# Hi, I am Me

# %%
print("Hello")
# Out:
# Hello
