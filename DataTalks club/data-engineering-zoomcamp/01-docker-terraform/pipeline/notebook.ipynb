# %%
import pandas as pd

# %%
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow'
url = f'{prefix}/yellow_tripdata_2021-01.csv.gz'
url
# Out:
# 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/yellow/yellow_tripdata_2021-01.csv.gz'

# %%
df = pd.read_csv(url)
# Out:
# C:\Users\Manas\AppData\Local\Temp\ipykernel_22676\4176769558.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
dtype = {
    "VendorID": "Int64",
    "passenger_count": "Int64",
    "trip_distance": "float64",
    "RatecodeID": "Int64",
    "store_and_fwd_flag": "string",
    "PULocationID": "Int64",
    "DOLocationID": "Int64",
    "payment_type": "Int64",
    "fare_amount": "float64",
    "extra": "float64",
    "mta_tax": "float64",
    "tip_amount": "float64",
    "tolls_amount": "float64",
    "improvement_surcharge": "float64",
    "total_amount": "float64",
    "congestion_surcharge": "float64"
}

parse_dates = [
    "tpep_pickup_datetime",
    "tpep_dropoff_datetime"
]

df = pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates
)

# %%
len(df)
# Out:
# 1369765

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df['VendorID']
# Out:
# 0             1
# 1             1
# 2             1
# 3             1
# 4             2
#            ...
# 1369760    <NA>
# 1369761    <NA>
# 1369762    <NA>
# 1369763    <NA>
# 1369764    <NA>
# Name: VendorID, Length: 1369765, dtype: Int64

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...           ...                  ...                   ...              ...
# 1369760      <NA>  2021-01-25 08:32:04   2021-01-25 08:49:32             <NA>
# 1369761      <NA>  2021-01-25 08:34:00   2021-01-25 09:04:00             <NA>
# 1369762      <NA>  2021-01-25 08:37:00   2021-01-25 08:53:00             <NA>
# 1369763      <NA>  2021-01-25 08:28:00   2021-01-25 08:50:00             <NA>
# 1369764      <NA>  2021-01-25 08:38:00   2021-01-25 08:50:00             <NA>
#
# ...

# %%
# !uv add sqlalchemy 
# Comment, because
# As, I already installed this library in 1st-time.

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Manas\AppData\Local\Programs\Python\Python311\python.exe

# %%
import sqlalchemy # pyright: ignore
sqlalchemy.__version__
# Out:
# '2.0.46'

# %%
# %pip install python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from sqlalchemy import create_engine # pyright: ignore
# engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

password = os.getenv("POSTGRES_PASSWORD")
engine = create_engine(
    f"postgresql+psycopg2://postgres:{password}@localhost:5432/ny_taxi"
)

with engine.connect() as conn:
    print("Connected Successfully")
# Out:
# Connected Successfully

# %%
# df.to_sql(name='yellow_taxi_data', con=engine)
# Don't run it as it will take a long time to run.

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge]
# Index: []

# %%
df.head(0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
len(df)
# Out:
# 1369765

# %%
df_iter = pd.read_csv( # df_iter => df_iterator
    url, 
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=10000,
)

# %%
df = next(df_iter) # Each time next 1000 data-set.
df
# Out:
#       VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 1000         2  2021-01-01 00:45:42   2021-01-01 00:55:54                1
# 1001         2  2021-01-01 00:58:55   2021-01-01 01:09:33                1
# 1002         1  2021-01-01 00:19:16   2021-01-01 00:36:58                1
# 1003         2  2021-01-01 00:03:18   2021-01-01 00:26:12                1
# 1004         1  2021-01-01 00:09:48   2021-01-01 00:28:59                1
# ...        ...                  ...                   ...              ...
# 1995         2  2021-01-01 01:39:31   2021-01-01 01:55:07                1
# 1996         2  2021-01-01 02:01:46   2021-01-01 02:05:44                1
# 1997         2  2021-01-01 00:59:56   2021-01-01 01:13:34                1
# 1998         1  2021-01-01 01:08:42   2021-01-01 01:20:47                1
# 1999         1  2021-01-01 01:29:30   2021-01-01 01:31:49                1
#
#       trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# ...

# %%
# %pip install tqdm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from tqdm.auto import tqdm # pyright: ignore

# %%
for df_chunk in df_iter:
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append',
                    index=False, method="mutli", chunksize=10000)
